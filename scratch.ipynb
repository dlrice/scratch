# %%
import numpy as np

# %%
a = np.array([[74, 26, 69], [23, 12, 25], [39, 22, 46]])

# %%
a
# Out:
# array([[74, 26, 69],
#        [23, 12, 25],
#        [39, 22, 46]])

# %%
sum(a)
# Out:
# array([136,  60, 140])

# %%
a.sum(axis=1)
# Out:
# array([169,  60, 107])

# %%
b = np.array([[97, 24, 35], [26, 0, 17], [28, 19, 45]])

# %%
a
# Out:
# array([[74, 26, 69],
#        [23, 12, 25],
#        [39, 22, 46]])

# %%
b
# Out:
# array([[97, 24, 35],
#        [26,  0, 17],
#        [28, 19, 45]])

# %%
a - a.T
# Out:
# array([[  0,   3,  30],
#        [ -3,   0,   3],
#        [-30,  -3,   0]])

# %%
b - b.T
# Out:
# array([[ 0, -2,  7],
#        [ 2,  0, -2],
#        [-7,  2,  0]])

# %%
a2 = np.fliplr(a)
print a2 - a2.T
# Out:
# [[  0   1  28]
#  [ -1   0   1]
#  [-28  -1   0]]

# %%
# Out:
# array([[  0,   1,  28],
#        [ -1,   0,   1],
#        [-28,  -1,   0]])

# %%
b2 = np.fliplr(b)
print b2 - b2.T
# Out:
# [[  0   7  52]
#  [ -7   0   7]
#  [-52  -7   0]]

# %%
a
# Out:
# array([[74, 26, 69],
#        [23, 12, 25],
#        [39, 22, 46]])

# %%
b
# Out:
# array([[97, 24, 35],
#        [26,  0, 17],
#        [28, 19, 45]])

# %%
a.conjugate()
# Out:
# array([[74, 26, 69],
#        [23, 12, 25],
#        [39, 22, 46]])

# %%
a
# Out:
# array([[74, 26, 69],
#        [23, 12, 25],
#        [39, 22, 46]])

# %%
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.imshow(a)

# %%
plt.imshow(b)

# %%
plt.imshow(a - a.T)

# %%
plt.imshow(b- b.T)
